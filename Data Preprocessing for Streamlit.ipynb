# %%
import pandas as pd

data = {
    'type': ['TV'],
    'source': ['Manga'],
    'episodes': [12],
    'duration': ['24 min. per ep.'],
    'rating': ['PG - Children'],
    'members': [70127],
    'genre': ['Comedy, Drama, Magic, Romance, Fantasy']
}

df = pd.DataFrame(data)

# %%
df.head()
# Out:
#   type source  episodes         duration         rating  members  \
# 0   TV  Manga        12  24 min. per ep.  PG - Children    70127
#
#                                     genre
# 0  Comedy, Drama, Magic, Romance, Fantasy

# %%
genres = df['genre'].str.get_dummies(sep=', ')
df = pd.concat([df, genres], axis=1)
df.drop('genre', axis=1, inplace=True)
columns_to_encode = ['type', 'source', 'duration', 'rating']
encoded_df = pd.get_dummies(df, columns=columns_to_encode)
df = pd.concat([df, encoded_df], axis=1)
new_columns_to_drop = ['type', 'source', 'duration', 'rating']
df = df.drop(new_columns_to_drop, axis=1)

# %%
import joblib  # For loading the .pkl file
from sklearn.ensemble import RandomForestRegressor

# %%
df.columns
# Out:
# Index(['episodes', 'members', 'Comedy', 'Drama', 'Fantasy', 'Magic', 'Romance',
#        'episodes', 'members', 'Comedy', 'Drama', 'Fantasy', 'Magic', 'Romance',
#        'type_TV', 'source_Manga', 'duration_24 min. per ep.',
#        'rating_PG - Children'],
#       dtype='object')

# %%
original_column_list = ['episodes', 'members', 'Action', 'Adventure', 'Cars', 'Comedy', 'Dementia', 'Demons', 'Drama', 'Ecchi', 'Fantasy', 'Game', 'Harem', 'Hentai', 'Historical', 'Horror', 'Josei', 'Kids', 'Magic', 'Martial Arts', 'Mecha', 'Military', 'Music', 'Mystery', 'Parody', 'Police', 'Psychological', 'Romance', 'Samurai', 'School', 'Sci-Fi', 'Seinen', 'Shoujo', 'Shoujo Ai', 'Shounen', 'Shounen Ai', 'Slice of Life', 'Space', 'Sports', 'Super Power', 'Supernatural', 'Thriller', 'Vampire', 'Yaoi', 'Yuri', 'episodes', 'members', 'Action', 'Adventure', 'Cars', 'Comedy', 'Dementia', 'Demons', 'Drama', 'Ecchi', 'Fantasy', 'Game', 'Harem', 'Hentai', 'Historical', 'Horror', 'Josei', 'Kids', 'Magic', 'Martial Arts', 'Mecha', 'Military', 'Music', 'Mystery', 'Parody', 'Police', 'Psychological', 'Romance', 'Samurai', 'School', 'Sci-Fi', 'Seinen', 'Shoujo', 'Shoujo Ai', 'Shounen', 'Shounen Ai', 'Slice of Life', 'Space', 'Sports', 'Super Power', 'Supernatural', 'Thriller', 'Vampire', 'Yaoi', 'Yuri', 'type_Movie', 'type_Music', 'type_ONA', 'type_OVA', 'type_Special', 'type_TV', 'type_Unknown', 'source_4-koma manga', 'source_Book', 'source_Card game', 'source_Digital manga', 'source_Game', 'source_Light novel', 'source_Manga', 'source_Music', 'source_Novel', 'source_Original', 'source_Other', 'source_Picture book', 'source_Radio', 'source_Unknown', 'source_Visual novel', 'source_Web manga', 'duration_1 hr.', 'duration_1 hr. 1 min.', 'duration_1 hr. 10 min.', 'duration_1 hr. 11 min.', 'duration_1 hr. 12 min.', 'duration_1 hr. 13 min.', 'duration_1 hr. 14 min.', 'duration_1 hr. 14 min. per ep.', 'duration_1 hr. 15 min.', 'duration_1 hr. 15 min. per ep.', 'duration_1 hr. 16 min.', 'duration_1 hr. 16 min. per ep.', 'duration_1 hr. 17 min.', 'duration_1 hr. 17 min. per ep.', 'duration_1 hr. 18 min.', 'duration_1 hr. 19 min.', 'duration_1 hr. 2 min.', 'duration_1 hr. 2 min. per ep.', 'duration_1 hr. 20 min.', 'duration_1 hr. 21 min.', 'duration_1 hr. 22 min.', 'duration_1 hr. 23 min.', 'duration_1 hr. 24 min.', 'duration_1 hr. 24 min. per ep.', 'duration_1 hr. 25 min.', 'duration_1 hr. 26 min.', 'duration_1 hr. 27 min.', 'duration_1 hr. 28 min.', 'duration_1 hr. 29 min.', 'duration_1 hr. 3 min.', 'duration_1 hr. 3 min. per ep.', 'duration_1 hr. 30 min.', 'duration_1 hr. 30 min. per ep.', 'duration_1 hr. 31 min.', 'duration_1 hr. 32 min.', 'duration_1 hr. 33 min.', 'duration_1 hr. 34 min.', 'duration_1 hr. 35 min.', 'duration_1 hr. 35 min. per ep.', 'duration_1 hr. 36 min.', 'duration_1 hr. 36 min. per ep.', 'duration_1 hr. 37 min.', 'duration_1 hr. 38 min.', 'duration_1 hr. 39 min.', 'duration_1 hr. 4 min.', 'duration_1 hr. 40 min.', 'duration_1 hr. 41 min.', 'duration_1 hr. 42 min.', 'duration_1 hr. 43 min.', 'duration_1 hr. 44 min.', 'duration_1 hr. 45 min.', 'duration_1 hr. 46 min.', 'duration_1 hr. 47 min.', 'duration_1 hr. 48 min.', 'duration_1 hr. 49 min.', 'duration_1 hr. 5 min.', 'duration_1 hr. 5 min. per ep.', 'duration_1 hr. 50 min.', 'duration_1 hr. 51 min.', 'duration_1 hr. 52 min.', 'duration_1 hr. 52 min. per ep.', 'duration_1 hr. 53 min.', 'duration_1 hr. 54 min.', 'duration_1 hr. 55 min.', 'duration_1 hr. 56 min.', 'duration_1 hr. 57 min.', 'duration_1 hr. 58 min.', 'duration_1 hr. 59 min.', 'duration_1 hr. 6 min.', 'duration_1 hr. 7 min.', 'duration_1 hr. 7 min. per ep.', 'duration_1 hr. 8 min.', 'duration_1 hr. 9 min.', 'duration_1 hr. per ep.', 'duration_1 min.', 'duration_1 min. per ep.', 'duration_10 min.', 'duration_10 min. per ep.', 'duration_10 sec.', 'duration_10 sec. per ep.', 'duration_11 min.', 'duration_11 min. per ep.', 'duration_12 min.', 'duration_12 min. per ep.', 'duration_12 sec.', 'duration_12 sec. per ep.', 'duration_13 min.', 'duration_13 min. per ep.', 'duration_13 sec.', 'duration_14 min.', 'duration_14 min. per ep.', 'duration_14 sec.', 'duration_14 sec. per ep.', 'duration_15 min.', 'duration_15 min. per ep.', 'duration_15 sec.', 'duration_15 sec. per ep.', 'duration_16 min.', 'duration_16 min. per ep.', 'duration_16 sec.', 'duration_16 sec. per ep.', 'duration_17 min.', 'duration_17 min. per ep.', 'duration_17 sec.', 'duration_18 min.', 'duration_18 min. per ep.', 'duration_18 sec.', 'duration_19 min.', 'duration_19 min. per ep.', 'duration_19 sec. per ep.', 'duration_2 hr.', 'duration_2 hr. 1 min.', 'duration_2 hr. 10 min.', 'duration_2 hr. 11 min.', 'duration_2 hr. 12 min.', 'duration_2 hr. 14 min.', 'duration_2 hr. 15 min.', 'duration_2 hr. 16 min.', 'duration_2 hr. 17 min.', 'duration_2 hr. 19 min.', 'duration_2 hr. 2 min.', 'duration_2 hr. 20 min.', 'duration_2 hr. 21 min.', 'duration_2 hr. 3 min.', 'duration_2 hr. 30 min.', 'duration_2 hr. 31 min.', 'duration_2 hr. 32 min.', 'duration_2 hr. 33 min.', 'duration_2 hr. 4 min.', 'duration_2 hr. 40 min.', 'duration_2 hr. 41 min.', 'duration_2 hr. 42 min.', 'duration_2 hr. 43 min.', 'duration_2 hr. 47 min.', 'duration_2 hr. 5 min.', 'duration_2 hr. 6 min.', 'duration_2 hr. 7 min.', 'duration_2 hr. 8 min.', 'duration_2 min.', 'duration_2 min. per ep.', 'duration_20 min.', 'duration_20 min. per ep.', 'duration_20 sec.', 'duration_20 sec. per ep.', 'duration_21 min.', 'duration_21 min. per ep.', 'duration_21 sec.', 'duration_21 sec. per ep.', 'duration_22 min.', 'duration_22 min. per ep.', 'duration_22 sec.', 'duration_22 sec. per ep.', 'duration_23 min.', 'duration_23 min. per ep.', 'duration_23 sec.', 'duration_24 min.', 'duration_24 min. per ep.', 'duration_24 sec. per ep.', 'duration_25 min.', 'duration_25 min. per ep.', 'duration_25 sec.', 'duration_25 sec. per ep.', 'duration_26 min.', 'duration_26 min. per ep.', 'duration_26 sec.', 'duration_26 sec. per ep.', 'duration_27 min.', 'duration_27 min. per ep.', 'duration_27 sec.', 'duration_28 min.', 'duration_28 min. per ep.', 'duration_28 sec.', 'duration_29 min.', 'duration_29 min. per ep.', 'duration_29 sec.', 'duration_29 sec. per ep.', 'duration_3 hr. 51 min.', 'duration_3 min.', 'duration_3 min. per ep.', 'duration_30 min.', 'duration_30 min. per ep.', 'duration_30 sec.', 'duration_30 sec. per ep.', 'duration_31 min.', 'duration_31 min. per ep.', 'duration_31 sec.', 'duration_31 sec. per ep.', 'duration_32 min.', 'duration_32 min. per ep.', 'duration_32 sec.', 'duration_32 sec. per ep.', 'duration_33 min.', 'duration_33 min. per ep.', 'duration_33 sec.', 'duration_33 sec. per ep.', 'duration_34 min.', 'duration_34 min. per ep.', 'duration_34 sec.', 'duration_34 sec. per ep.', 'duration_35 min.', 'duration_35 min. per ep.', 'duration_35 sec.', 'duration_35 sec. per ep.', 'duration_36 min.', 'duration_36 min. per ep.', 'duration_36 sec.', 'duration_36 sec. per ep.', 'duration_37 min.', 'duration_37 min. per ep.', 'duration_37 sec.', 'duration_37 sec. per ep.', 'duration_38 min.', 'duration_38 min. per ep.', 'duration_38 sec.', 'duration_38 sec. per ep.', 'duration_39 min.', 'duration_39 min. per ep.', 'duration_39 sec.', 'duration_39 sec. per ep.', 'duration_4 min.', 'duration_4 min. per ep.', 'duration_40 min.', 'duration_40 min. per ep.', 'duration_40 sec.', 'duration_40 sec. per ep.', 'duration_41 min.', 'duration_41 min. per ep.', 'duration_41 sec.', 'duration_41 sec. per ep.', 'duration_42 min.', 'duration_42 min. per ep.', 'duration_42 sec.', 'duration_42 sec. per ep.', 'duration_43 min.', 'duration_43 min. per ep.', 'duration_44 min.', 'duration_44 min. per ep.', 'duration_44 sec.', 'duration_44 sec. per ep.', 'duration_45 min.', 'duration_45 min. per ep.', 'duration_45 sec.', 'duration_45 sec. per ep.', 'duration_46 min.', 'duration_46 min. per ep.', 'duration_46 sec.', 'duration_46 sec. per ep.', 'duration_47 min.', 'duration_47 min. per ep.', 'duration_48 min.', 'duration_48 min. per ep.', 'duration_49 min.', 'duration_49 min. per ep.', 'duration_49 sec.', 'duration_49 sec. per ep.', 'duration_5 min.', 'duration_5 min. per ep.', 'duration_50 min.', 'duration_50 min. per ep.', 'duration_50 sec.', 'duration_51 min.', 'duration_51 min. per ep.', 'duration_51 sec.', 'duration_51 sec. per ep.', 'duration_52 min.', 'duration_52 min. per ep.', 'duration_52 sec.', 'duration_53 min.', 'duration_53 min. per ep.', 'duration_53 sec. per ep.', 'duration_54 min.', 'duration_54 min. per ep.', 'duration_54 sec.', 'duration_54 sec. per ep.', 'duration_55 min.', 'duration_55 min. per ep.', 'duration_55 sec.', 'duration_56 min.', 'duration_56 sec. per ep.', 'duration_57 min.', 'duration_57 min. per ep.', 'duration_57 sec.', 'duration_57 sec. per ep.', 'duration_58 min.', 'duration_58 min. per ep.', 'duration_58 sec.', 'duration_58 sec. per ep.', 'duration_59 min.', 'duration_6 min.', 'duration_6 min. per ep.', 'duration_7 min.', 'duration_7 min. per ep.', 'duration_7 sec.', 'duration_8 min.', 'duration_8 min. per ep.', 'duration_9 min.', 'duration_9 min. per ep.', 'duration_Unknown', 'rating_G - All Ages', 'rating_PG - Children', 'rating_PG-13 - Teens 13 or older', 'rating_R - 17+ (violence & profanity)', 'rating_R+ - Mild Nudity', 'rating_Rx - Hentai']

# %%
new_df = pd.DataFrame(0, index=[0], columns=original_column_list)

# Update values from df for existing columns
common_columns = list(set(original_column_list) & set(df.columns))
new_df[common_columns] = df[common_columns].iloc[0]
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_11664\3481568309.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   new_df[common_columns] = df[common_columns].iloc[0]

# %%
new_df.head()
# Out:
#    episodes  members  Action  Adventure  Cars  Comedy  Dementia  Demons  \
# 0        12    70127       0          0     0       1         0       0
#
#    Drama  Ecchi  ...  duration_8 min. per ep.  duration_9 min.  \
# 0      1      0  ...                        0                0
#
#    duration_9 min. per ep.  duration_Unknown  rating_G - All Ages  \
# 0                        0                 0                    0
#
#    rating_PG - Children  rating_PG-13 - Teens 13 or older  \
# 0                  True                                 0
#
#    rating_R - 17+ (violence & profanity)  rating_R+ - Mild Nudity  \
# 0                                      0                        0
#
#    rating_Rx - Hentai
# 0                   0
#
# [1 rows x 417 columns]

# %%
final_input = new_df

# %%
pd.set_option('display.max_rows', None)
final_input_list = final_input.columns.tolist()
pd.Series(final_input_list)
# Out:
# 0                                   episodes
# 1                                    members
# 2                                     Action
# 3                                  Adventure
# 4                                       Cars
# 5                                     Comedy
# 6                                   Dementia
# 7                                     Demons
# 8                                      Drama
# 9                                      Ecchi
# 10                                   Fantasy
# 11                                      Game
# 12                                     Harem
# 13                                    Hentai
# 14                                Historical
# 15                                    Horror
# 16                                     Josei
# 17                                      Kids
# 18                                     Magic
# 19                              Martial Arts
# 20                                     Mecha
# 21                                  Military
# 22                                     Music
# 23                                   Mystery
# 24                                    Parody
# 25                                    Police
# 26                             Psychological
# 27                                   Romance
# 28                                   Samurai
# 29                                    School
# 30                                    Sci-Fi
# 31                                    Seinen
# 32                                    Shoujo
# 33                                 Shoujo Ai
# 34                                   Shounen
# 35                                Shounen Ai
# 36                             Slice of Life
# 37                                     Space
# 38                                    Sports
# 39                               Super Power
# 40                              Supernatural
# 41                                  Thriller
# 42                                   Vampire
# 43                                      Yaoi
# 44                                      Yuri
# 45                                  episodes
# 46                                   members
# 47                                    Action
# 48                                 Adventure
# 49                                      Cars
# 50                                    Comedy
# 51                                  Dementia
# 52                                    Demons
# 53                                     Drama
# 54                                     Ecchi
# 55                                   Fantasy
# 56                                      Game
# 57                                     Harem
# 58                                    Hentai
# 59                                Historical
# 60                                    Horror
# 61                                     Josei
# 62                                      Kids
# 63                                     Magic
# 64                              Martial Arts
# 65                                     Mecha
# 66                                  Military
# 67                                     Music
# 68                                   Mystery
# 69                                    Parody
# 70                                    Police
# 71                             Psychological
# 72                                   Romance
# 73                                   Samurai
# 74                                    School
# 75                                    Sci-Fi
# 76                                    Seinen
# 77                                    Shoujo
# 78                                 Shoujo Ai
# 79                                   Shounen
# 80                                Shounen Ai
# 81                             Slice of Life
# 82                                     Space
# 83                                    Sports
# 84                               Super Power
# 85                              Supernatural
# 86                                  Thriller
# 87                                   Vampire
# 88                                      Yaoi
# 89                                      Yuri
# 90                                type_Movie
# 91                                type_Music
# 92                                  type_ONA
# 93                                  type_OVA
# 94                              type_Special
# 95                                   type_TV
# 96                              type_Unknown
# 97                       source_4-koma manga
# 98                               source_Book
# 99                          source_Card game
# 100                     source_Digital manga
# 101                              source_Game
# 102                       source_Light novel
# 103                             source_Manga
# 104                             source_Music
# 105                             source_Novel
# 106                          source_Original
# 107                             source_Other
# 108                      source_Picture book
# 109                             source_Radio
# 110                           source_Unknown
# 111                      source_Visual novel
# 112                         source_Web manga
# 113                           duration_1 hr.
# 114                    duration_1 hr. 1 min.
# 115                   duration_1 hr. 10 min.
# 116                   duration_1 hr. 11 min.
# 117                   duration_1 hr. 12 min.
# 118                   duration_1 hr. 13 min.
# 119                   duration_1 hr. 14 min.
# 120           duration_1 hr. 14 min. per ep.
# 121                   duration_1 hr. 15 min.
# 122           duration_1 hr. 15 min. per ep.
# 123                   duration_1 hr. 16 min.
# 124           duration_1 hr. 16 min. per ep.
# 125                   duration_1 hr. 17 min.
# 126           duration_1 hr. 17 min. per ep.
# 127                   duration_1 hr. 18 min.
# 128                   duration_1 hr. 19 min.
# 129                    duration_1 hr. 2 min.
# 130            duration_1 hr. 2 min. per ep.
# 131                   duration_1 hr. 20 min.
# 132                   duration_1 hr. 21 min.
# 133                   duration_1 hr. 22 min.
# 134                   duration_1 hr. 23 min.
# 135                   duration_1 hr. 24 min.
# 136           duration_1 hr. 24 min. per ep.
# 137                   duration_1 hr. 25 min.
# 138                   duration_1 hr. 26 min.
# 139                   duration_1 hr. 27 min.
# 140                   duration_1 hr. 28 min.
# 141                   duration_1 hr. 29 min.
# 142                    duration_1 hr. 3 min.
# 143            duration_1 hr. 3 min. per ep.
# 144                   duration_1 hr. 30 min.
# 145           duration_1 hr. 30 min. per ep.
# 146                   duration_1 hr. 31 min.
# 147                   duration_1 hr. 32 min.
# 148                   duration_1 hr. 33 min.
# 149                   duration_1 hr. 34 min.
# 150                   duration_1 hr. 35 min.
# 151           duration_1 hr. 35 min. per ep.
# 152                   duration_1 hr. 36 min.
# 153           duration_1 hr. 36 min. per ep.
# 154                   duration_1 hr. 37 min.
# 155                   duration_1 hr. 38 min.
# 156                   duration_1 hr. 39 min.
# 157                    duration_1 hr. 4 min.
# 158                   duration_1 hr. 40 min.
# 159                   duration_1 hr. 41 min.
# 160                   duration_1 hr. 42 min.
# 161                   duration_1 hr. 43 min.
# 162                   duration_1 hr. 44 min.
# 163                   duration_1 hr. 45 min.
# 164                   duration_1 hr. 46 min.
# 165                   duration_1 hr. 47 min.
# 166                   duration_1 hr. 48 min.
# 167                   duration_1 hr. 49 min.
# 168                    duration_1 hr. 5 min.
# 169            duration_1 hr. 5 min. per ep.
# 170                   duration_1 hr. 50 min.
# 171                   duration_1 hr. 51 min.
# 172                   duration_1 hr. 52 min.
# 173           duration_1 hr. 52 min. per ep.
# 174                   duration_1 hr. 53 min.
# 175                   duration_1 hr. 54 min.
# 176                   duration_1 hr. 55 min.
# 177                   duration_1 hr. 56 min.
# 178                   duration_1 hr. 57 min.
# 179                   duration_1 hr. 58 min.
# 180                   duration_1 hr. 59 min.
# 181                    duration_1 hr. 6 min.
# 182                    duration_1 hr. 7 min.
# 183            duration_1 hr. 7 min. per ep.
# 184                    duration_1 hr. 8 min.
# 185                    duration_1 hr. 9 min.
# 186                   duration_1 hr. per ep.
# 187                          duration_1 min.
# 188                  duration_1 min. per ep.
# 189                         duration_10 min.
# 190                 duration_10 min. per ep.
# 191                         duration_10 sec.
# 192                 duration_10 sec. per ep.
# 193                         duration_11 min.
# 194                 duration_11 min. per ep.
# 195                         duration_12 min.
# 196                 duration_12 min. per ep.
# 197                         duration_12 sec.
# 198                 duration_12 sec. per ep.
# 199                         duration_13 min.
# 200                 duration_13 min. per ep.
# 201                         duration_13 sec.
# 202                         duration_14 min.
# 203                 duration_14 min. per ep.
# 204                         duration_14 sec.
# 205                 duration_14 sec. per ep.
# 206                         duration_15 min.
# 207                 duration_15 min. per ep.
# 208                         duration_15 sec.
# 209                 duration_15 sec. per ep.
# 210                         duration_16 min.
# 211                 duration_16 min. per ep.
# 212                         duration_16 sec.
# 213                 duration_16 sec. per ep.
# 214                         duration_17 min.
# 215                 duration_17 min. per ep.
# 216                         duration_17 sec.
# 217                         duration_18 min.
# 218                 duration_18 min. per ep.
# 219                         duration_18 sec.
# 220                         duration_19 min.
# 221                 duration_19 min. per ep.
# 222                 duration_19 sec. per ep.
# 223                           duration_2 hr.
# 224                    duration_2 hr. 1 min.
# 225                   duration_2 hr. 10 min.
# 226                   duration_2 hr. 11 min.
# 227                   duration_2 hr. 12 min.
# 228                   duration_2 hr. 14 min.
# 229                   duration_2 hr. 15 min.
# 230                   duration_2 hr. 16 min.
# 231                   duration_2 hr. 17 min.
# 232                   duration_2 hr. 19 min.
# 233                    duration_2 hr. 2 min.
# 234                   duration_2 hr. 20 min.
# 235                   duration_2 hr. 21 min.
# 236                    duration_2 hr. 3 min.
# 237                   duration_2 hr. 30 min.
# 238                   duration_2 hr. 31 min.
# 239                   duration_2 hr. 32 min.
# 240                   duration_2 hr. 33 min.
# 241                    duration_2 hr. 4 min.
# 242                   duration_2 hr. 40 min.
# 243                   duration_2 hr. 41 min.
# 244                   duration_2 hr. 42 min.
# 245                   duration_2 hr. 43 min.
# 246                   duration_2 hr. 47 min.
# 247                    duration_2 hr. 5 min.
# 248                    duration_2 hr. 6 min.
# 249                    duration_2 hr. 7 min.
# 250                    duration_2 hr. 8 min.
# 251                          duration_2 min.
# 252                  duration_2 min. per ep.
# 253                         duration_20 min.
# 254                 duration_20 min. per ep.
# 255                         duration_20 sec.
# 256                 duration_20 sec. per ep.
# 257                         duration_21 min.
# 258                 duration_21 min. per ep.
# 259                         duration_21 sec.
# 260                 duration_21 sec. per ep.
# 261                         duration_22 min.
# 262                 duration_22 min. per ep.
# 263                         duration_22 sec.
# 264                 duration_22 sec. per ep.
# 265                         duration_23 min.
# 266                 duration_23 min. per ep.
# 267                         duration_23 sec.
# 268                         duration_24 min.
# 269                 duration_24 min. per ep.
# 270                 duration_24 sec. per ep.
# 271                         duration_25 min.
# 272                 duration_25 min. per ep.
# 273                         duration_25 sec.
# 274                 duration_25 sec. per ep.
# 275                         duration_26 min.
# 276                 duration_26 min. per ep.
# 277                         duration_26 sec.
# 278                 duration_26 sec. per ep.
# 279                         duration_27 min.
# 280                 duration_27 min. per ep.
# 281                         duration_27 sec.
# 282                         duration_28 min.
# 283                 duration_28 min. per ep.
# 284                         duration_28 sec.
# 285                         duration_29 min.
# 286                 duration_29 min. per ep.
# 287                         duration_29 sec.
# 288                 duration_29 sec. per ep.
# 289                   duration_3 hr. 51 min.
# 290                          duration_3 min.
# 291                  duration_3 min. per ep.
# 292                         duration_30 min.
# 293                 duration_30 min. per ep.
# 294                         duration_30 sec.
# 295                 duration_30 sec. per ep.
# 296                         duration_31 min.
# 297                 duration_31 min. per ep.
# 298                         duration_31 sec.
# 299                 duration_31 sec. per ep.
# 300                         duration_32 min.
# 301                 duration_32 min. per ep.
# 302                         duration_32 sec.
# 303                 duration_32 sec. per ep.
# 304                         duration_33 min.
# 305                 duration_33 min. per ep.
# 306                         duration_33 sec.
# 307                 duration_33 sec. per ep.
# 308                         duration_34 min.
# 309                 duration_34 min. per ep.
# 310                         duration_34 sec.
# 311                 duration_34 sec. per ep.
# 312                         duration_35 min.
# 313                 duration_35 min. per ep.
# 314                         duration_35 sec.
# 315                 duration_35 sec. per ep.
# 316                         duration_36 min.
# 317                 duration_36 min. per ep.
# 318                         duration_36 sec.
# 319                 duration_36 sec. per ep.
# 320                         duration_37 min.
# 321                 duration_37 min. per ep.
# 322                         duration_37 sec.
# 323                 duration_37 sec. per ep.
# 324                         duration_38 min.
# 325                 duration_38 min. per ep.
# 326                         duration_38 sec.
# 327                 duration_38 sec. per ep.
# 328                         duration_39 min.
# 329                 duration_39 min. per ep.
# 330                         duration_39 sec.
# 331                 duration_39 sec. per ep.
# 332                          duration_4 min.
# 333                  duration_4 min. per ep.
# 334                         duration_40 min.
# 335                 duration_40 min. per ep.
# 336                         duration_40 sec.
# 337                 duration_40 sec. per ep.
# 338                         duration_41 min.
# 339                 duration_41 min. per ep.
# 340                         duration_41 sec.
# 341                 duration_41 sec. per ep.
# 342                         duration_42 min.
# 343                 duration_42 min. per ep.
# 344                         duration_42 sec.
# 345                 duration_42 sec. per ep.
# 346                         duration_43 min.
# 347                 duration_43 min. per ep.
# 348                         duration_44 min.
# 349                 duration_44 min. per ep.
# 350                         duration_44 sec.
# 351                 duration_44 sec. per ep.
# 352                         duration_45 min.
# 353                 duration_45 min. per ep.
# 354                         duration_45 sec.
# 355                 duration_45 sec. per ep.
# 356                         duration_46 min.
# 357                 duration_46 min. per ep.
# 358                         duration_46 sec.
# 359                 duration_46 sec. per ep.
# 360                         duration_47 min.
# 361                 duration_47 min. per ep.
# 362                         duration_48 min.
# 363                 duration_48 min. per ep.
# 364                         duration_49 min.
# 365                 duration_49 min. per ep.
# 366                         duration_49 sec.
# 367                 duration_49 sec. per ep.
# 368                          duration_5 min.
# 369                  duration_5 min. per ep.
# 370                         duration_50 min.
# 371                 duration_50 min. per ep.
# 372                         duration_50 sec.
# 373                         duration_51 min.
# 374                 duration_51 min. per ep.
# 375                         duration_51 sec.
# 376                 duration_51 sec. per ep.
# 377                         duration_52 min.
# 378                 duration_52 min. per ep.
# 379                         duration_52 sec.
# 380                         duration_53 min.
# 381                 duration_53 min. per ep.
# 382                 duration_53 sec. per ep.
# 383                         duration_54 min.
# 384                 duration_54 min. per ep.
# 385                         duration_54 sec.
# 386                 duration_54 sec. per ep.
# 387                         duration_55 min.
# 388                 duration_55 min. per ep.
# 389                         duration_55 sec.
# 390                         duration_56 min.
# 391                 duration_56 sec. per ep.
# 392                         duration_57 min.
# 393                 duration_57 min. per ep.
# 394                         duration_57 sec.
# 395                 duration_57 sec. per ep.
# 396                         duration_58 min.
# 397                 duration_58 min. per ep.
# 398                         duration_58 sec.
# 399                 duration_58 sec. per ep.
# 400                         duration_59 min.
# 401                          duration_6 min.
# 402                  duration_6 min. per ep.
# 403                          duration_7 min.
# 404                  duration_7 min. per ep.
# 405                          duration_7 sec.
# 406                          duration_8 min.
# 407                  duration_8 min. per ep.
# 408                          duration_9 min.
# 409                  duration_9 min. per ep.
# 410                         duration_Unknown
# 411                      rating_G - All Ages
# 412                     rating_PG - Children
# 413         rating_PG-13 - Teens 13 or older
# 414    rating_R - 17+ (violence & profanity)
# 415                  rating_R+ - Mild Nudity
# 416                       rating_Rx - Hentai
# dtype: object

# %%
import pandas as pd
import joblib  # For loading the .pkl file
from sklearn.ensemble import RandomForestRegressor  # Ensure scikit-learn is installed

# %%
model = joblib.load('random_forest_regressor.pkl')

# %%
predictions = model.predict(final_input)

# %%
predictions
# Out:
# array([[7.7054, 7.7054]])

# %%
# Assuming predictions is the variable holding the array
single_prediction = predictions[0][0]  # Accessing the first element of the first array
print(single_prediction)
# Out:
# 7.7054000000000045
